# %% [markdown]
# # Imports

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Análise Exploratória dos Dados

# %%
dados = pd.read_csv('Customer-Data - 2.csv')
dados.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
dados.shape
# Out:
# (8950, 18)

# %%
dados.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204822        592.437371
# std     2081.531879           0.236904   2136.634780       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
dados.dtypes
# Out:
# CUST_ID                              object
# BALANCE                             float64
# BALANCE_FREQUENCY                   float64
# PURCHASES                           float64
# ONEOFF_PURCHASES                    float64
# INSTALLMENTS_PURCHASES              float64
# CASH_ADVANCE                        float64
# PURCHASES_FREQUENCY                 float64
# ONEOFF_PURCHASES_FREQUENCY          float64
# PURCHASES_INSTALLMENTS_FREQUENCY    float64
# CASH_ADVANCE_FREQUENCY              float64
# CASH_ADVANCE_TRX                      int64
# PURCHASES_TRX                         int64
# CREDIT_LIMIT                        float64
# PAYMENTS                            float64
# MINIMUM_PAYMENTS                    float64
# PRC_FULL_PAYMENT                    float64
# TENURE                                int64
# dtype: object

# %%
dados.columns
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE'],
#       dtype='object')

# %% [markdown]
# Verificando presença de valores nulos

# %%
dados.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
box_minimum_pay = sns.boxplot(dados.MINIMUM_PAYMENTS, orient='h')
box_minimum_pay.figure.set_size_inches(16, 3)

# %% [markdown]
# Apenas um valor faltante na coluna CREDIT_LIMIT, optamos por remove-lo

# %%
remove = dados.query('CREDIT_LIMIT.isna() == True').index
dados.drop(remove, inplace=True)

# %% [markdown]
# Queremos substituir os valores faltantes da coluna MINIMUM_PAYMENTS pela média, uma vez que é uma coluna de valores quantitativos contínuos. Para isso vamos remover os outliers que estão completamente destoantes dos demais

# %%
id_delete = dados.query('MINIMUM_PAYMENTS > 35000').index
dados.drop(id_delete, inplace=True)

# %%
dados.fillna(dados.MINIMUM_PAYMENTS.mean(), inplace=True)
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8942 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8942 non-null   object
#  1   BALANCE                           8942 non-null   float64
#  2   BALANCE_FREQUENCY                 8942 non-null   float64
#  3   PURCHASES                         8942 non-null   float64
#  4   ONEOFF_PURCHASES                  8942 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8942 non-null   float64
#  6   CASH_ADVANCE                      8942 non-null   float64
#  7   PURCHASES_FREQUENCY               8942 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8942 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8942 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8942 non-null   float64
# ...

# %% [markdown]
# # Boxplot

# %%
box = sns.boxplot(dados, orient='h')
box.figure.set_size_inches(16, 12)

# %% [markdown]
# # Heatmap

# %%
df_numeric = dados.select_dtypes(include=['float64', 'int64'])

correlation_matrix = df_numeric.corr()

plt.figure(figsize=(30, 20))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
plt.show()

# %% [markdown]
# # Normalize

# %%
from sklearn.preprocessing import StandardScaler

colunas_selecionadas = [
    'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
    'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
    'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
    'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
    'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
    'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE'
]

df_selecionado = dados[colunas_selecionadas]
scaler = StandardScaler()
df_normalizado = df_selecionado.copy()
df_normalizado[colunas_selecionadas] = scaler.fit_transform(df_normalizado[colunas_selecionadas])

# %% [markdown]
# ### Matrix de correlação normalizada

# %%
corrmat = df_normalizado.corr()

plt.figure(figsize=(30, 20))
sns.heatmap(corrmat, annot=True, cmap="coolwarm", linewidths=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fb4c14ead1ba> in <cell line: 1>()
# ----> 1 corrmat = df_normalizado.corr()
#       2
#       3 plt.figure(figsize=(20, 30))
#       4 sns.heatmap(corrmat, annot=True, cmap="coolwarm", linewidths=0.5)
#       5 plt.show()
#
# NameError: name 'df_normalizado' is not defined

# %% [markdown]
# # KMeans

# %%
from sklearn.cluster import KMeans

inertias = []
for i in range(1,10):
  # kmeans++ ira selecionar os clusters baseado em dristribuição de probabilidade empírica
  # dos pontos, ela acelera a convergencia do método.
  km = KMeans(n_clusters=i, init = 'k-means++', random_state=321, n_init='auto')
  km.fit(df_normalizado)
  inertias.append(km.inertia_)

plt.figure(figsize=(10,5))
plt.plot([x for x in range(1,10)], inertias, marker='o')
plt.xlabel('K')
plt.ylabel('Inertia')
plt.show()

# %%
from sklearn.metrics import silhouette_score

inertias = []
silhs = []
for i in range(2, 11):  # Silhouette score não faz sentido para 1 cluster
    km = KMeans(n_clusters=i, init='k-means++', random_state=321, n_init='auto')
    km.fit(df_normalizado)
    silhouette_avg = silhouette_score(df_normalizado, km.labels_)
    silhs.append(silhouette_avg)
    print(f'Silhouette Score for {i} clusters = {silhouette_avg:.6f}')
    inertias.append(km.inertia_)

plt.figure(figsize=(10,5))
plt.plot(np.arange(2,11), silhs, marker='o')
plt.xlabel('K')
plt.ylabel('Silhouette Score')
plt.show()
# Out:
# Silhouette Score for 2 clusters = 0.208721
# Silhouette Score for 3 clusters = 0.252357
# Silhouette Score for 4 clusters = 0.199836
# Silhouette Score for 5 clusters = 0.191576
# Silhouette Score for 6 clusters = 0.200937
# Silhouette Score for 7 clusters = 0.209206
# Silhouette Score for 8 clusters = 0.194038
# Silhouette Score for 9 clusters = 0.190669
# Silhouette Score for 10 clusters = 0.198860

# %%
from sklearn.cluster import KMeans

# Aplicar o KMeans com 3 clusters
km_3_clusters = KMeans(n_clusters=3, init='k-means++', random_state=321, n_init='auto')
km_3_clusters.fit(df_normalizado)

# Adicionar os rótulos dos clusters ao DataFrame original
dados['ClusterKMeans'] = km_3_clusters.labels_

# Mostrar os primeiros registros do DataFrame com os clusters
dados.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
df_pca = pca.fit_transform(df_normalizado)

dados['PCA1'] = df_pca[:, 0]
dados['PCA2'] = df_pca[:, 1]

# Plotar os clusters visualmente
plt.figure(figsize=(8, 6))
sns.scatterplot(x='PCA1', y='PCA2', hue='ClusterKMeans', data=dados, palette='viridis', s=100, alpha=0.7)
plt.title('KMeans - Visualização dos Clusters com PCA')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

# Aplicar PCA para reduzir para 3 dimensões
pca_3d = PCA(n_components=3)
df_pca_3d = pca_3d.fit_transform(df_normalizado)

dados['PCA1'] = df_pca_3d[:, 0]
dados['PCA2'] = df_pca_3d[:, 1]
dados['PCA3'] = df_pca_3d[:, 2]


fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')


sc = ax.scatter(dados['PCA1'], dados['PCA2'], dados['PCA3'], c=dados['ClusterKMeans'], cmap='viridis', s=50, alpha=0.7)


ax.set_xlabel('PCA1')
ax.set_ylabel('PCA2')
ax.set_zlabel('PCA3')
plt.title('KMeans - Visualização dos Clusters em 3D com PCA')
plt.colorbar(sc)
plt.show()

# %%
dados.groupby('ClusterKMeans').mean(numeric_only=True)[["BALANCE", "PURCHASES", "CREDIT_LIMIT"]]
# Out:
#                    BALANCE    PURCHASES  CREDIT_LIMIT
# ClusterKMeans
# 0              2187.053950  4280.386015   7712.387938
# 1              4028.856928   394.115641   6723.692069
# 2               798.127369   504.038319   3272.818589

# %% [markdown]
# # DBSCAN

# %%
from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=1.8, min_samples=10)
dblabels = dbscan.fit_predict(df_normalizado)

dados['ClusterDB'] = dblabels

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
df_pca = pca.fit_transform(df_normalizado)

dados['PCA1'] = df_pca[:, 0]
dados['PCA2'] = df_pca[:, 1]

# Plotar os clusters visualmente
plt.figure(figsize=(5, 4))
sns.scatterplot(x='PCA1', y='PCA2', hue='ClusterDB', data=dados, palette='viridis', s=100, alpha=0.7)
plt.title('DBSCAN - Visualização dos Clusters com PCA')
plt.show()

# %%
fig = plt.figure(figsize=(5, 4))
ax = fig.add_subplot(111, projection='3d')


sc = ax.scatter(dados['PCA1'], dados['PCA2'], dados['PCA3'], c=dados['ClusterDB'], cmap='viridis', s=50, alpha=0.7)


ax.set_xlabel('PCA1')
ax.set_ylabel('PCA2')
ax.set_zlabel('PCA3')
plt.title('DBSCAN - Visualização dos Clusters em 3D com PCA')
plt.colorbar(sc)
plt.show()

# %%
silhouette_avg = silhouette_score(df_normalizado, dados['ClusterKMeans'])
print(f'Silhouette Score para KMeans: {float(silhouette_avg):.4f}')
# Out:
# Silhouette Score para KMeans: 0.2524

# %%
silhouette_avg = silhouette_score(df_normalizado, dados['ClusterDB'])
print(f'Silhouette Score para DBSCAN: {float(silhouette_avg):.4f}')
# Out:
# Silhouette Score para DBSCAN: 0.4102

# %%
dados.groupby('ClusterDB').mean(numeric_only=True)
# Out:
#                BALANCE  BALANCE_FREQUENCY    PURCHASES  ONEOFF_PURCHASES  \
# ClusterDB
# -1         3896.890859           0.922713  3555.426384       2297.603162
#  0         1269.792605           0.871595   684.960960        380.745390
#
#            INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ClusterDB
# -1                    1258.451505   3285.690621             0.669370
#  0                     304.475219    691.752523             0.468053
#
#            ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# ClusterDB
# -1                           0.404280                          0.503730
#  0                           0.177535                          0.346959
#
#            CASH_ADVANCE_FREQUENCY  ...  PURCHASES_TRX  CREDIT_LIMIT  \
# ClusterDB                          ...
# -1                       0.292584  ...      41.479798   8767.949495
#  0                       0.115606  ...      11.361796   3960.683870
#
# ...

# %% [markdown]
# # HDBSCAN

# %%
from sklearn.cluster import HDBSCAN

for i in range(2, 8):
    hdb = HDBSCAN(min_cluster_size=i)
    hdb.fit(df_normalizado)

    dados['ClusterHDB'] = hdb.labels_

    silhouette_avg = silhouette_score(df_normalizado, dados['ClusterHDB'])
    print(f'Silhouette Score para {i} Cluster-Size: {float(silhouette_avg):.4f}')
# Out:
# Silhouette Score para 2 Cluster-Size: -0.1259
# Silhouette Score para 3 Cluster-Size: -0.4111
# Silhouette Score para 4 Cluster-Size: 0.5807
# Silhouette Score para 5 Cluster-Size: -0.4786
# Silhouette Score para 6 Cluster-Size: -0.4673
# Silhouette Score para 7 Cluster-Size: -0.4310

# %%
hdb = HDBSCAN(min_cluster_size=4)
hdb.fit(df_normalizado)

dados['ClusterHDB'] = hdb.labels_

# %%
plt.figure(figsize=(5, 4))
sns.scatterplot(x='PCA1', y='PCA2', hue='ClusterHDB', data=dados, palette='viridis', s=100, alpha=0.7)
plt.title('HDBSCAN - Visualização dos Clusters com PCA')
plt.show()

# %%
fig = plt.figure(figsize=(5, 4))
ax = fig.add_subplot(111, projection='3d')


sc = ax.scatter(dados['PCA1'], dados['PCA2'], dados['PCA3'], c=dados['ClusterHDB'], cmap='viridis', s=50, alpha=0.7)


ax.set_xlabel('PCA1')
ax.set_ylabel('PCA2')
ax.set_zlabel('PCA3')
plt.title('HDBSCAN - Visualização dos Clusters em 3D com PCA')
plt.colorbar(sc)
plt.show()

# %%
dados.groupby('ClusterHDB').mean(numeric_only=True)
# Out:
#                 BALANCE  BALANCE_FREQUENCY    PURCHASES  ONEOFF_PURCHASES  \
# ClusterHDB
# -1          5243.804168           0.950700  6821.431513       4349.073616
#  0          2491.257501           0.954546   181.500000        129.225000
#  1          1444.274340           0.874864   821.470597        475.885966
#  2          3132.043572           1.000000   236.987500        149.625000
#
#             INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ClusterHDB
# -1                      2474.65310   4747.825530             0.751807
#  0                        52.27500   7859.187296             0.157197
#  1                       345.82297    858.255290             0.482431
#  2                        87.36250    121.682600             0.242424
#
#             ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# ClusterHDB
# -1                            0.469023                          0.613761
# ...

# %%
from sklearn.metrics import davies_bouldin_score, calinski_harabasz_score

# %%
silhouetteHDB = silhouette_score(df_normalizado, dados['ClusterHDB'])
silhouetteDB = silhouette_score(df_normalizado, dados['ClusterDB'])
silhouetteKMeans = silhouette_score(df_normalizado, dados['ClusterKMeans'])
print(f'Silhouette Score KMeans: {float(silhouetteKMeans):.4f}\nSilhouette Score HDBScan: {float(silhouetteHDB):.4f}\nSilhouette Score DBScan: {float(silhouetteDB):.4f}\n')

# Davies-Bouldin Score (menores valores, melhor cluster)
dbiHDB = davies_bouldin_score(df_normalizado, dados['ClusterHDB'])
dbiDB = davies_bouldin_score(df_normalizado, dados['ClusterDB'])
dbiKMeans = davies_bouldin_score(df_normalizado, dados['ClusterKMeans'])
print(f'Davies-Bouldin Score KMeans: {float(dbiKMeans):.4f}\nDavies-Bouldin Score HDBScan: {float(dbiHDB):.4f}\nDavies-Bouldin Score DBScan: {float(dbiDB):.4f}\n')

# Calinski-Harabasz Index (maiores valores, melhor cluster)
chHDB = calinski_harabasz_score(df_normalizado, dados['ClusterHDB'])
chDB = calinski_harabasz_score(df_normalizado, dados['ClusterDB'])
chKMeans = calinski_harabasz_score(df_normalizado, dados['ClusterKMeans'])
print(f'Calinski-Harabasz Score KMeans: {float(chKMeans):.4f}\nCalinski-Harabasz Score HDBScan: {float(chHDB):.4f}\nCalinski-Harabasz Score DBScan: {float(chDB):.4f}\n')
# Out:
# Silhouette Score KMeans: 0.2524
# Silhouette Score HDBScan: 0.5807
# Silhouette Score DBScan: 0.4102
#
# Davies-Bouldin Score KMeans: 1.5997
# Davies-Bouldin Score HDBScan: 1.1994
# Davies-Bouldin Score DBScan: 2.2767
#
# Calinski-Harabasz Score KMeans: 1612.9487
# Calinski-Harabasz Score HDBScan: 349.4050
# Calinski-Harabasz Score DBScan: 1011.8558
